# %%
import csv
import operator
import decimal
count = 0
with open ('Resources/budget_data.csv','r') as csv_file:
    csv_reader = csv.reader(csv_file)
    next(csv_reader)
    data = []
    for line in csv_reader:
        data.append(line[1])
        
differences = []
for i in range(len(data)-1):
    count = count + 1
    elem_current = float(data[i])
    elem_next = float(data[i+1])
    difference = elem_next - elem_current
    differences.append(difference)
        
#differences
#dataframe = pd.read_csv('Resources/budget_data.csv')
#print('dataframe')
    #for line in csv_reader:
    #    count = count +1
    #    print(line[1])
        
    #for i in range(len(csv_reader)-1):
    #    count += 1
    #    print(csv_reader[i][1] * csv_reader[i+1],1)
        
        #df.loc[df['Profit/Losses'] == 310503]
        #dif= line[1]
#count
#data

# %%
avg_diff_2 = sum(differences)/len(differences)
val = 'Feb-2012'
valm = 'Sept-2013'
maxVal = data[0]
minVal = data[0]

for b in range(0, len(data),1):
    maxVal = max(maxVal,data[b])
    minVal = min(minVal,data[b])

#print("max:", maxVal)
#"print("min", minVal)

print("Budget Data Analysis")
print("Total of Months ",count)
num = round(avg_diff_2, 2)
print("Average change on Profits and Losses",num)
print("Greatest increase in Profits ",val,data[25])
print("Greatest decrease in Profits ",valm,data[44])
# Out:
# Budget Data Analysis
# Total of Months  85
# Average change on Profits and Losses -2315.12
# Greatest increase in Profits  Feb-2012 1170593
# Greatest decrease in Profits  Sept-2013 -1196225

# %%
#with open ('Resources/budget_data.csv','w') as results:
#    csv_writer = csv.writer(results, delimiter ='-') #'\t'
#    csv_writer = csv.writer(results)
#next(csv_writer)

# %%
sample = open('Resources/budget_data.csv','r')
csv1 = csv.reader(sample,delimiter=',')
sort = sorted(csv1,key=operator.itemgetter(0))
for eachline in sort:
    print (eachline)

datat = eachline

DateValue = datat[0]
minValue = datat[0]

for b in range(0, len(datat),1):
    LatestD = max(DateValue,datat[b])
    LatestV = min(minValue,datat[b])
    
print("Most recent Operation Date ",LatestD)
print("Most recent Operation Amount ",LatestV)
eachline

#with open ('Resources/budget_data.csv','rb') as csv_filed:
#    columns=dict([(x[0],x[1:]) for x in zip(*allrows)])
#    csv_rd = csv.DictReader(csv_filed)
#    for row in csv_rd:
#        count = count +1
        #print(row)
#        print(line['Profit/Losses'].value)
        
#with open('Resources/budget_data.csv') as f:
#----       print(csv.reader(f))
#    reader = list(csv.reader(f))
    #print [dict(zip(reader[0],x)) for x in reader]
    #print map(lambda x:dict(zip(reader[0],x)), reader)
# Out:
# ['Apr-2010', '-69417']
# ['Apr-2011', '793163']
# ['Apr-2012', '1151518']
# ['Apr-2013', '471435']
# ['Apr-2014', '581943']
# ['Apr-2015', '-524626']
# ['Apr-2016', '757143']
# ['Aug-2010', '604885']
# ['Aug-2011', '668179']
# ['Aug-2012', '-1022534']
# ['Aug-2013', '999942']
# ['Aug-2014', '800701']
# ['Aug-2015', '840723']
# ['Aug-2016', '569899']
# ['Date', 'Profit/Losses']
# ['Dec-2010', '-80353']
# ['Dec-2011', '309978']
# ['Dec-2012', '542494']
# ['Dec-2013', '1150461']
# ['Dec-2014', '988505']
# ['Dec-2015', '778237']
# ['Dec-2016', '60988']
# ['Feb-2010', '984655']
# ['Feb-2011', '-335203']
# ['Feb-2012', '1170593']
# ['Feb-2013', '321469']
# ['Feb-2014', '617856']
# ['Feb-2015', '1029471']
# ['Feb-2016', '-1100387']
# ['Feb-2017', '671099']
# ['Jan-2010', '867884']
# ['Jan-2011', '779806']
# ['Jan-2012', '-755566']
# ['Jan-2013', '359333']
# ['Jan-2014', '682458']
# ['Jan-2015', '1139715']
# ['Jan-2016', '650000']
# ['Jan-2017', '138230']
# ['Jul-2010', '1033096']
# ...

# %%
#f=open('Resources/budget_data.csv','r')
#reader = csv.reader(f)
#budgetd = {}
#for row in reader:
#    budgetd(row[0]) = {'Date':row[1],'Profit/Loss':[2]}

# %%
#Profits = []
#Losses = []
#dater = reader


#for i in range(len(reader)-1):
    #count = count + 1
 #   if (i >= 0):
        #Date.append(i)
  #      Profits.append(i) 
  #  else:
        #Date.append(i)
  #      Losses.append(i) 
        
   # elem_current = float(data[i])
   # elem_next = float(data[i+1])
   ## difference = elem_next - elem_current
   # differences.append(difference)
            
#print("Profits List",Profits)
#print("Losses List",Losses)

# %%
#avg_diff_2 = sum(differences)/len(differences)
#print(avg_diff_2)
#print(data)
#for line in csv_reader:
#        count = count +1
#        print(line[1])
#count = 0
#i = 0


#Funcion----------------------------------------------------------------------
#def next_reader(csv_file):
#    with open(csv_file) as f:
#        reader = csv.reader(f)
#        check = 0
#        curr_and_next = []
#        while True:
#            if check == 0:
#                first = reader.next()
#                second = reader.next()
#                curr_and_next = [first, second]
#                check = 1
#            else:
##                curr_and_next = [curr_and_next[1], reader.next()]
 #           yield curr_and_next
 #       print(curr_and_next)
#----------------------------------------------------------------------------
    #for i in range(len(csv_reader)-1):
    #for i in range(len(csv_reader)-1):
        #count += 1
     #   Pro_Lo.append(i)
        #print(csv_reader[i][1] - csv_reader[i+1],1)
      #  Pr_Lo
    #print(count)
        
    #csv_reader = csv.reader(csv_file)
##Reading as Dict sgmt---------------------------------------------
#allrows=list(csv.reader(open('Resources/budget_data.csv')))
#with open ('Resources/budget_data.csv','rb') as csv_file:
    #columns=dict([(x[0],x[1:]) for x in zip(*allrows)])
    
#rows = []
#for row in csv.DictReader('Resources/budget_data.csv', dialect='excel', delimiter=','):
    #rows.append(row)
 #   print(row)
    
    #csv_reader = csv.DictReader(csv_file)
    #for row in csv_reader:
    #    count = count +1
      #  print(row)
       # print(row['Profit/Losses'])
##*******--------------------------------------------------SI FUNCIONA      
#f = open('Resources/budget_data.csv','r')
#lines = f.readlines()
#for i in lines[0:]:
#    split_line = i.split()
#    var1 = split_line[0]
##*******-----------------------------------------------------
    #print(var1)
 #   var2 = split_line[1]
  #  var3 = split_line[3]
    
    #for row_index, row in enumerate(csv.DictReader(csv_file)):
    #if row_index % N != M: continue
    #do_something_useful_with(row)
    
    
    #with open('file.csv','rb') as f:
    #    reader = csv.reader(f)
    #    for row in reader:
    #        print row
            
    
        #print(Fecha: line['Date'])
        #print(line['Profit/Losses'])
    #print("Budget Data Analysis")
    #print("Total of Months are ",count)
    #print(line['Date'])
    
    #print("Total Amounts of Profits and Losses during the entire period $",sum_ProfiLoss)
    #print("Numero count)
##--------------------------------------------------------writer sgmt
    #with open ('csv_writer','w') as new_csv_file:
    #    csv_writer = csv.writer(new_csv_file, delimiter ='-') #'\t'
        #csv_writer = csv.writer(new_file):
    #next(csv_reader)
## Reading----------------------------------------------------------

    #for row in csv_reader:
    #    total = total + float(row)
              #  print(total)
        
        # for line in csv_reader:
       #     wordList = line.split()
       #     numLines += 1
            #numWords += len(wordsList)
           # numChars += len(line)
            
#print "Lines: %i\nWords: %i" %(numLines)
            
            #print(line)
            
#lines = [line for line in open(csv_reader)]
            #print(line)
            #print(line['Profit/Losses'])
             #print(line['Date'])
              #print (line[0])#...there´s only line[0] and line[1]
            #line[0].strip()
            #line[0].strip().split(',')
            #print(line[0])
         # csv_writer.writerow(line)
#--------------------------------------------------------------------------
#D = print(line['Date'])
#PnL = print(line['Profit/Loss'])
#count = 0
#print ('D')
#def sum(data):
#    suma = 0
#    for element in data:
#        suma += element
#    return suma
#print(sumar(data))
#---------------------------------------------------------------------------

# %%
#______________________________________________________________________________
#print("Greatest Decrease in Profits / Date "+str(dataframe['Date'].min()))
                                            #+str(dataframe['Profit/Losses'].min()))
#print("Greatest Decrease in Profits / Date "+str(var.min()))
#print("Greatest Decrease in Profits / Amount $"+str(dataframe['Profit/Losses'].min()))
#print(var)
#dataframe.loc[26,26]
#dataframe.head(87)
#Pr_Lo = csv_reader['Profit/Losses'].tolist()
#Date = dataframe['Date'].tolist()
#print("The list of numbers are", Pr_Lo)
#print ("El conjunto de fechas son", Date)

# %%
import sys
#type(Profits)
TProfits = tuple(Profits)
TLosses = tuple(Losses)
#print(TProfits[0:86])
print(TLosses[0:86])
#TProfits
#pd.DataFrame(column = Losses)
#pd.DataFrame(column=Profits)
# Out:
# ()

# %%
#print("Budget Data Analysis")
#print("Budget Data Analysis")
    #for ele in csv_reader:
    #   count = count + 1
     #   print("Total of Months are ()",format(count()))
        #print("Total of Months "+str(line['Date'].count()))
#Pr_Lo
#print("Total of Months are ",count)
#print("Total of Months "+str(dataframe['Date'].count()))
#print("Total Amounts of Profits and Losses during the entire period $",sum_ProfiLoss)
#print("Average in changes Profits and Losses / Date "+str(dataframe['Date','Amount'].max()))
#print("Average in changes Profits and Losses"+str(dataframe['Amount'].max()))
##"Average in changes Profits and Losses / Date "+str(dataframe['Amount'].max()))
#print("Average in changes Date "+str(dataframe['Profit/Losses'].mean()))
#print("Average in changes Profits and Losses / Amount  "+str(dataframe['Profit/Losses'].mean()))
#print("Average in changes Profits and Losses Amount $ "+str(dataframe['Profit/Losses'].mean()))
#print("The net total amount of "Profit/Losses" over the entire period "+str(dataframe['Profit/Losses'].sum()))

#print("Greatest Increase in Profits"+str(dataframe['Date'].max()))
#---print("Greatest Increase in Profits "+str(dataframe.loc[25,:]))
#print("Greatest Increase in Profits / Amount $"+str(dataframe['Profit/Losses'].max()))
#var = dataframe['Date'].extend(dataframe['Profit/Losses'])
#----print("Greatest Decrease in Profits "+str(dataframe.loc[44, :]))

#print("Greatest Decrease in Profits / Date "+str(dataframe['Date'].min()))
                                            #+str(dataframe['Profit/Losses'].min()))
#print("Greatest Decrease in Profits / Date "+str(var.min()))
#print("Greatest Decrease in Profits / Amount $"+str(dataframe['Profit/Losses'].min()))
#print(var)
#dataframe.loc[26,26]
